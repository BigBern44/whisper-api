# %%
import asyncio
import aiohttp
import time

async def send_request(session, file_path, i):
    url = "http://localhost:8000/subtitles"
    with open(file_path, "rb") as f:
        data = aiohttp.FormData()
        data.add_field("file", f, filename="input.mp4", content_type="video/mp4")
        async with session.post(url, data=data) as resp:
            result = await resp.json()
            print(f"[{i}] {result}")
            return result

file_path = "input.mp4"
n_requests = 10

start = time.time()

async with aiohttp.ClientSession() as session:
    tasks = [send_request(session, file_path, i) for i in range(n_requests)]
    results = await asyncio.gather(*tasks)

elapsed = time.time() - start
print(f"\n{n_requests} requêtes en {elapsed:.2f}s ({n_requests/elapsed:.1f} req/s)")
# Out:
# [65] {'job_id': 'a25baa31-591f-45c9-a9f5-2fada406f79b', 'status': 'pending'}
# [80] {'job_id': '85cb39d6-7092-49e2-a8e1-6eea9295c369', 'status': 'pending'}
# [42] {'job_id': 'b0611811-a78f-479f-8d33-d26a29afbdf7', 'status': 'pending'}
# [66] {'job_id': 'c04c7e8f-71c8-4b6d-ae09-bfedcd5e7d6f', 'status': 'pending'}
# [69] {'job_id': '72a4dfad-5759-412f-950d-08f38bc08c01', 'status': 'pending'}
# [79] {'job_id': '72f705bd-618f-4fd1-aad3-98dce5163cb5', 'status': 'pending'}
# [46] {'job_id': '16797a87-7397-4a0e-8f9e-5e429daf93e9', 'status': 'pending'}
# [73] {'job_id': '0935bb7b-7048-4a7b-bd33-f21d188d9fca', 'status': 'pending'}
# [43] {'job_id': 'd0b8d143-27ad-41d6-bb78-4b660a197a81', 'status': 'pending'}
# [77] {'job_id': 'f8eaa3cf-ac25-42b5-97a7-8233d66c07d7', 'status': 'pending'}
# [68] {'job_id': 'e010dd78-9062-43a7-9e90-e170c5ecc732', 'status': 'pending'}
# [38] {'job_id': 'df57b3bd-4f0f-450b-898b-eaed20f1e753', 'status': 'pending'}
# [71] {'job_id': 'af03b979-0f8e-4e72-a11d-53bdbcba1d5e', 'status': 'pending'}
# [78] {'job_id': '067fa4c1-3917-43d7-a518-0d52f33810e2', 'status': 'pending'}
# [75] {'job_id': '61fbf15a-90d8-4ddd-8e1c-28d47cb9e004', 'status': 'pending'}
# [97] {'job_id': '904e9f56-bfd7-4a2b-bda7-dfe7f4569f72', 'status': 'pending'}
# [91] {'job_id': '574a325d-2ede-4e87-8267-de2629f9a86e', 'status': 'pending'}
# [84] {'job_id': '67958d87-5e36-44b2-8a18-106f2e0a4238', 'status': 'pending'}
# [55] {'job_id': '230e76f3-f256-46d7-9536-339f7ac7ebb0', 'status': 'pending'}
# [70] {'job_id': 'd1c08f49-e36f-4b28-8c98-e784a95b1238', 'status': 'pending'}
# [92] {'job_id': 'd4def670-86b5-4d7d-bdb6-1bddec13b37e', 'status': 'pending'}
# [81] {'job_id': '4fbf3e2e-3cc8-4b33-87f9-5435e7f0dc6a', 'status': 'pending'}
# [72] {'job_id': 'b42f9fc1-3b84-4e5a-aa8c-bf58dad1c914', 'status': 'pending'}
# [64] {'job_id': '1448cc49-b64d-433f-9ff6-37f46d5e4879', 'status': 'pending'}
# [82] {'job_id': '37fd80c7-ecc3-46bb-9ed9-886daac0dadd', 'status': 'pending'}
# [93] {'job_id': '71a7e505-854e-4dc3-b16a-6f33b0120fbf', 'status': 'pending'}
# [44] {'job_id': '1ddc4e43-9d0e-4738-a905-a334d45c86dc', 'status': 'pending'}
# [90] {'job_id': '9610a01b-7bf3-4676-a124-e6fbd18c4028', 'status': 'pending'}
# [88] {'job_id': 'c19d7ee8-0bb8-4b4e-9c12-acfa3abdf443', 'status': 'pending'}
# [86] {'job_id': '8a12e4f3-8b21-4be9-a0cf-d808c4f5c1dd', 'status': 'pending'}
# [89] {'job_id': '9f2b6dc7-ea16-41fb-88ea-de09afb8aeeb', 'status': 'pending'}
# [63] {'job_id': '538f1d5f-e765-466f-9cb3-298d8a41921d', 'status': 'pending'}
# [57] {'job_id': '7e45547f-417c-4ab3-9fc6-05f88a009759', 'status': 'pending'}
# [47] {'job_id': 'd5e0c429-382c-498f-ae83-aed535e34329', 'status': 'pending'}
# [85] {'job_id': '8e27ae0d-0fba-4555-b01c-ffda35ade765', 'status': 'pending'}
# [58] {'job_id': 'c26ec01f-a609-42ce-bc1f-7f876a4a52d7', 'status': 'pending'}
# [51] {'job_id': 'f0797989-e9f6-431b-ad40-ed79ce2a04a9', 'status': 'pending'}
# [83] {'job_id': 'd265c539-c9e5-4211-9f81-d4cc927ded48', 'status': 'pending'}
# [59] {'job_id': '0708b832-98c6-4462-821b-2654fdc15469', 'status': 'pending'}
# [87] {'job_id': '838994d2-a9e5-46a3-a624-4f62763e132e', 'status': 'pending'}
# [53] {'job_id': '81a0cb2a-5ffe-43ec-89e9-830d35a2a07b', 'status': 'pending'}
# [49] {'job_id': 'd19397e1-a4e2-418e-a7b4-a4f342281053', 'status': 'pending'}
# [61] {'job_id': '201faec2-783f-4152-9c27-bf126bd9866c', 'status': 'pending'}
# [62] {'job_id': '6182bcef-a530-4717-a354-3a4e5d169c29', 'status': 'pending'}
# [40] {'job_id': '146822e3-aebc-48c6-a467-1137472078d8', 'status': 'pending'}
# [60] {'job_id': 'a376ed82-d6ec-4616-bc48-d18eb5846506', 'status': 'pending'}
# [67] {'job_id': 'de13a8ee-908c-4419-a630-ea8aaa477865', 'status': 'pending'}
# [0] {'job_id': '9ed6a7e9-3916-4f77-bb48-8688848aaf66', 'status': 'pending'}
# [7] {'job_id': '57ecf885-70fd-4334-b810-08f25655ded0', 'status': 'pending'}
# [33] {'job_id': 'f144d0b0-4113-4a72-9cc3-d0410781fa07', 'status': 'pending'}
# [1] {'job_id': 'db11e794-6010-4cd4-b543-6262c544e306', 'status': 'pending'}
# [34] {'job_id': '95847dc6-4b2e-4261-ab06-eb1e1fbf427f', 'status': 'pending'}
# [22] {'job_id': 'ef6c00fc-178d-4f14-8377-1d05723629a6', 'status': 'pending'}
# [13] {'job_id': '335cbb8e-65cd-47a7-9c3c-00e57dde5db7', 'status': 'pending'}
# [14] {'job_id': '9c522412-46f3-4d5d-b8ce-c59afd4dacc5', 'status': 'pending'}
# [54] {'job_id': '21ab1775-6600-40f8-a7ce-5791442baa49', 'status': 'pending'}
# [48] {'job_id': 'a701b5fe-19c1-4381-8ecd-8a80dd0662cd', 'status': 'pending'}
# [50] {'job_id': 'f6b1d6d9-1614-49ed-82bb-39d621707655', 'status': 'pending'}
# [30] {'job_id': '46476d9c-c6d5-47cd-a04f-9c4dd4f34234', 'status': 'pending'}
# [32] {'job_id': '84519644-ebd3-4bab-ae6b-dc6f2333b2f7', 'status': 'pending'}
# [56] {'job_id': '4c85ebf6-39b6-463a-9b10-76d35dc9eb93', 'status': 'pending'}
# [19] {'job_id': 'f24ad658-44a6-4119-90ef-d5945e5de2ff', 'status': 'pending'}
# [9] {'job_id': 'f25063e0-b50d-44b8-ba9c-aa7c109bbe91', 'status': 'pending'}
# [5] {'job_id': 'c9d6ddb9-e91f-4069-8b29-239c4efbefd6', 'status': 'pending'}
# [52] {'job_id': '5eb76d94-c885-487c-972f-8a305ac37cde', 'status': 'pending'}
# [6] {'job_id': 'e14d2db0-3649-4702-909f-9f6be679ce38', 'status': 'pending'}
# [8] {'job_id': 'cc847ea2-0873-42a7-b61a-77cef878300a', 'status': 'pending'}
# [31] {'job_id': '6e39c757-d3e7-4de3-8f15-d27240afa563', 'status': 'pending'}
# [2] {'job_id': '97f21b8c-c1d5-4abe-aef2-52f0ebd13a43', 'status': 'pending'}
# [39] {'job_id': '1cf6aae2-3503-4115-b2cb-cc4ba5aa75dc', 'status': 'pending'}
# [15] {'job_id': 'b1552beb-27d5-4112-a52a-8631f34309d7', 'status': 'pending'}
# [20] {'job_id': '88943a4d-7711-4582-ae78-51999e7c0c9b', 'status': 'pending'}
# [11] {'job_id': '9f02c3a9-6443-4ce2-915c-27dc4d9b1626', 'status': 'pending'}
# [18] {'job_id': '722a0a4c-ea9b-437b-b0de-5b2a2409ec49', 'status': 'pending'}
# [17] {'job_id': 'b05906c9-0be3-49d0-9393-30fdc95c7e85', 'status': 'pending'}
# [95] {'job_id': 'f72139ee-c3a0-4b60-95ab-99ed83d176f9', 'status': 'pending'}
# [36] {'job_id': 'debb0b61-c84a-4578-a368-1da70b65928a', 'status': 'pending'}
# [24] {'job_id': 'fcde6097-924a-46d9-bb00-498ca1a8d1bb', 'status': 'pending'}
# [74] {'job_id': '3c35477f-7a25-4157-a767-4a66faa10aed', 'status': 'pending'}
# [45] {'job_id': 'f139f470-64d5-4d97-8770-edfec4128df9', 'status': 'pending'}
# [41] {'job_id': 'c852ded9-030c-4523-ac07-441eda5d4efe', 'status': 'pending'}
# [12] {'job_id': '437beec7-2a00-427c-82a9-d39790fcb2d1', 'status': 'pending'}
# [29] {'job_id': 'a3398fb3-8027-40d2-a58f-58179f11d148', 'status': 'pending'}
# [76] {'job_id': '317da33b-015b-416f-9cd7-7a47dc086830', 'status': 'pending'}
# [16] {'job_id': 'e59093b4-72ad-414b-9963-5c885735d22b', 'status': 'pending'}
# [28] {'job_id': '5b327e88-3a7a-41ef-9ee7-3081c36c2efe', 'status': 'pending'}
# [10] {'job_id': '7f09d488-35ad-40f2-b9bb-9b91f1657904', 'status': 'pending'}
# [21] {'job_id': '85446d0d-db8d-450c-b281-20ab29d53eae', 'status': 'pending'}
# [3] {'job_id': '7bd5f4de-7d15-4ef2-b9f6-a3c51d58f8c3', 'status': 'pending'}
# [4] {'job_id': '5ee16b3e-cbf8-41ff-862c-2dc302a4c4e6', 'status': 'pending'}
# [26] {'job_id': '0d3d5821-5078-4b30-bb5c-319c00b6193d', 'status': 'pending'}
# [99] {'job_id': '1a978dc4-48db-4e16-8747-3f08adc15453', 'status': 'pending'}
# [27] {'job_id': '2f741e2b-e43d-45ca-9953-cfad957aa571', 'status': 'pending'}
# [23] {'job_id': '8dc8c0b4-295a-4aec-80d6-4e48dbd0bca6', 'status': 'pending'}
# [94] {'job_id': 'ee9ec2d3-067c-4566-b936-a719807b8733', 'status': 'pending'}
# [35] {'job_id': '88853a84-bdc7-4b15-a2b8-8cef3c8364bc', 'status': 'pending'}
# [96] {'job_id': '45efbf0d-0313-41de-a6a4-79dc8ccad048', 'status': 'pending'}
# [37] {'job_id': '9a487362-a6fd-446d-aace-21c06f901c9e', 'status': 'pending'}
# [98] {'job_id': 'd2a9be5e-06d7-4290-88de-1280200269d0', 'status': 'pending'}
# [25] {'job_id': 'c2b317f1-ae90-45c6-860b-a35ce9c4fd3a', 'status': 'pending'}
#
# 100 requêtes en 16.52s (6.1 req/s)
